# %%
import pandas as pd
file_path = 'CISO.xlsx'

# %%
# Read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path)

# %%
df['Local time'] = pd.to_datetime(df['Local time'])

# Define the start and end dates for the range
start_date = '2019-01-01'
end_date = '2024-01-01'

#filter the DataFrame
filtered_df = df[(df['Local time'] >= start_date) & (df['Local time'] < end_date)]

# %% [markdown]
# Demand Froecast using LSTM

# %%
column_demand =['Local time','DF','Adjusted D']

# %%
df_demand = filtered_df[column_demand]

# %%
df_demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43824 entries, 30720 to 74543
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Local time  43824 non-null  datetime64[ns]
#  1   DF          43824 non-null  float64
#  2   Adjusted D  43824 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.3 MB

# %%
df_demand.head()
# Out:
#                Local time       DF  Adjusted D
# 30720 2019-01-01 00:00:00  23436.0     22803.0
# 30721 2019-01-01 01:00:00  22362.0     21965.0
# 30722 2019-01-01 02:00:00  21444.0     21216.0
# 30723 2019-01-01 03:00:00  20803.0     20631.0
# 30724 2019-01-01 04:00:00  20416.0     20299.0

# %%
import numpy as np
mape = np.mean(np.abs((df_demand['Adjusted D'] - df_demand['DF']) / df_demand['Adjusted D'])) * 100
print('MAPE of the forecasted data present in DataFrame:', mape)
# Out:
# MAPE of the forecasted data present in DataFrame: 8.923152765707808

# %%
temp = df_demand.copy() # make temporary copy of dataframe
dataset = temp['Adjusted D'].dropna().values # numpy.ndarray of the actual load
dataset = dataset.astype('float32') 
dataset = np.reshape(dataset, (-1, 1)) # reshape to one feature; required for the models
dataset
# Out:
# array([[22803.],
#        [21965.],
#        [21216.],
#        ...,
#        [25007.],
#        [24317.],
#        [23918.]], dtype=float32)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) # Min Max scaler
dataset = scaler.fit_transform(dataset) # fit and transform the dataset

# %%
dataset
# Out:
# array([[0.44605598],
#        [0.42965356],
#        [0.41499317],
#        ...,
#        [0.48919556],
#        [0.47568998],
#        [0.46788022]], dtype=float32)

# %%
# Train and Test splits
train_size = int(len(dataset) * 0.80) 
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
look_back = 25 # timesteps to lookback for predictions
X_train, trainY = create_dataset(train, look_back)
X_test, testY = create_dataset(test, look_back)

# %%
len(X_train)
X_train
#(batch_size, timesteps, features)
# Out:
# array([[0.44605598, 0.42965356, 0.41499317, ..., 0.49704444, 0.4669407 ,
#         0.43671954],
#        [0.42965356, 0.41499317, 0.4035428 , ..., 0.4669407 , 0.43671954,
#         0.4169505 ],
#        [0.41499317, 0.4035428 , 0.39704445, ..., 0.43671954, 0.4169505 ,
#         0.40317088],
#        ...,
#        [0.49412802, 0.4925426 , 0.48459584, ..., 0.4637894 , 0.46594247,
#         0.47234294],
#        [0.4925426 , 0.48459584, 0.48348016, ..., 0.46594247, 0.47234294,
#         0.47048348],
#        [0.48459584, 0.48348016, 0.49733806, ..., 0.47234294, 0.47048348,
#         0.46962225]], dtype=float32)

# %%
trainY
# Out:
# array([0.4169505 , 0.40317088, 0.3965551 , ..., 0.47048348, 0.46962225,
#        0.48017225], dtype=float32)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
print("Shapes: \nTraining set: {}, Testing set: {}".format(X_train.shape, X_test.shape))
print("Sample from training set: \n{}".format(X_train[0]))
# Out:
# Shapes:
# Training set: (35033, 1, 25), Testing set: (8739, 1, 25)
# Sample from training set:
# [[0.44605598 0.42965356 0.41499317 0.4035428  0.39704445 0.39755335
#   0.40647876 0.42123705 0.41922098 0.4038168  0.39097673 0.37944806
#   0.3680564  0.3593071  0.36012918 0.37216678 0.39776865 0.44717166
#   0.5126444  0.5267959  0.5233901  0.51546293 0.49704444 0.4669407
#   0.43671954]]

# %% [markdown]
# AutoRegressive
# An autoregressive (AR) model predicts future behavior based on past behavior. The process is basically a linear regression of the data in the current series against one or more past values in the same series.

# %%
from statsmodels.tsa.ar_model import  AutoReg
lags = 25
model = AutoReg(train,lags=lags)
model_fit = model.fit()

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout,Dense
from sklearn.metrics import mean_squared_error,mean_absolute_error, accuracy_score, classification_report

# %%
test_predict = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# invert predictions
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform(test)
print('Test Mean Absolute Error:', mean_absolute_error(Y_test, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test, test_predict)))
# Out:
# Test Mean Absolute Error: 3013.151472614155
# Test Root Mean Squared Error: 4121.641134074582

# %%
Y_test
# Out:
# array([[26468.],
#        [26047.],
#        [25240.],
#        ...,
#        [25007.],
#        [24317.],
#        [23918.]], dtype=float32)

# %%
test_predict
# Out:
# array([[26141.17859608],
#        [26101.21156623],
#        [25773.58289138],
#        ...,
#        [24965.1645046 ],
#        [24965.16452434],
#        [24965.1645325 ]])

# %%
mape = np.mean(np.abs((Y_test - test_predict) / Y_test)) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 11.915021173871173

# %%
import matplotlib.pyplot as plt
import seaborn as sns
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# Moving Average
# The moving average (MA) is a simple technical analysis tool that smooths out price data by creating a constantly updated average price. The average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks or any time period the trader chooses. We are taking moving average of 25 hours hence we can use the data we prepared for LSTM.

# %%
test_predict = np.mean(X_test, axis=2)
print('Test Mean Absolute Error:', mean_absolute_error(testY, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(testY, test_predict)))
# Out:
# Test Mean Absolute Error: 0.04286583
# Test Root Mean Squared Error: 0.053635698

# %%
testY
# Out:
# array([0.4923077 , 0.4912116 , 0.48201215, ..., 0.5049521 , 0.48919556,
#        0.47568998], dtype=float32)

# %%
Y_test_value = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
Y_test_value
# Out:
# array([[25166.],
#        [25110.],
#        [24640.],
#        ...,
#        [25812.],
#        [25007.],
#        [24317.]], dtype=float32)

# %%
test_predict_value = scaler.inverse_transform(test_predict.reshape(-1, 1))

# %%
test_predict_value
# Out:
# array([[21580.879],
#        [21528.8  ],
#        [21491.322],
#        ...,
#        [22826.803],
#        [22833.64 ],
#        [22810.559]], dtype=float32)

# %%
mape = np.mean(np.abs((Y_test_value - test_predict_value) / Y_test_value)) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 8.662478625774384

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, testY[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# ARMA
# An ARMA model, or Autoregressive Moving Average model, is used to describe weakly stationary stochastic time series in terms of two polynomials. The first of these polynomials is for autoregression, the second for the moving average.

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'train' is your training data
order = (2, 0, 1)  # ARIMA order: (p, d, q)
model = ARIMA(train, order=order)
model_fit = model.fit()

# %%
test_predict = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# invert predictions
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform(test)
print('Test Mean Absolute Error:', mean_absolute_error(Y_test, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test, test_predict)))
# Out:
# Test Mean Absolute Error: 3058.6738609053887
# Test Root Mean Squared Error: 4146.076288010142

# %%
mape = np.mean(np.abs((Y_test - test_predict) / Y_test)) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 12.11620191021095

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# LSTM
# Long short-term memory is an artificial recurrent neural network architecture used in the field of deep learning. Unlike standard feedforward neural networks, LSTM has feedback connections. It can not only process single data points, but also entire sequences of data

# %%
temp = df_demand.copy() # make temporary copy of dataframe
dataset = temp['Adjusted D'].dropna().values # numpy.ndarray of the actual load
dataset = dataset.astype('float32') 
dataset = np.reshape(dataset, (-1, 1)) # reshape to one feature; required for the models
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)
    
look_back = 25
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
dataset
# Out:
# array([[0.44605598],
#        [0.42965356],
#        [0.41499317],
#        ...,
#        [0.48919556],
#        [0.47568998],
#        [0.46788022]], dtype=float32)

# %%
X_test
# Out:
# array([[[0.51779217, 0.5095518 , 0.49375612, ..., 0.4038951 ,
#          0.43814838, 0.48471326]],
#
#        [[0.5095518 , 0.49375612, 0.4786064 , ..., 0.43814838,
#          0.48471326, 0.4923077 ]],
#
#        [[0.49375612, 0.4786064 , 0.46670583, ..., 0.48471326,
#          0.4923077 , 0.4912116 ]],
#
#        ...,
#
#        [[0.50160503, 0.50048935, 0.49712273, ..., 0.45314154,
#          0.47218636, 0.5086123 ]],
#
#        [[0.50048935, 0.49712273, 0.4932668 , ..., 0.47218636,
#          0.5086123 , 0.5049521 ]],
#
#        [[0.49712273, 0.4932668 , 0.4828538 , ..., 0.5086123 ,
#          0.5049521 , 0.48919556]]], dtype=float32)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test),verbose=1, shuffle=False)

model.summary()
# Out:
# Epoch 1/200
# 501/501 [==============================] - 3s 3ms/step - loss: 0.0047 - val_loss: 8.2048e-04
# Epoch 2/200
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 5.5720e-04
# Epoch 3/200
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 4/200
# 501/501 [==============================] - 1s 2ms/step - loss: 9.6240e-04 - val_loss: 0.0011
# Epoch 5/200
# 501/501 [==============================] - 1s 2ms/step - loss: 8.1487e-04 - val_loss: 6.3846e-04
# Epoch 6/200
# 501/501 [==============================] - 1s 2ms/step - loss: 7.1368e-04 - val_loss: 4.8807e-04
# Epoch 7/200
# 501/501 [==============================] - 1s 2ms/step - loss: 6.3715e-04 - val_loss: 3.7536e-04
# Epoch 8/200
# 501/501 [==============================] - 1s 2ms/step - loss: 5.6009e-04 - val_loss: 3.7433e-04
# Epoch 9/200
# 501/501 [==============================] - 1s 2ms/step - loss: 5.0719e-04 - val_loss: 2.1072e-04
# Epoch 10/200
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7257e-04 - val_loss: 2.5672e-04
# Epoch 11/200
# 501/501 [==============================] - 1s 2ms/step - loss: 4.4538e-04 - val_loss: 5.4746e-04
# Epoch 12/200
# 501/501 [==============================] - 1s 2ms/step - loss: 3.9612e-04 - val_loss: 1.5649e-04
# Epoch 13/200
# 501/501 [==============================] - 1s 2ms/step - loss: 3.5612e-04 - val_loss: 1.4904e-04
# Epoch 14/200
# 501/501 [==============================] - 1s 2ms/step - loss: 3.2564e-04 - val_loss: 1.4811e-04
# Epoch 15/200
# 501/501 [==============================] - 1s 2ms/step - loss: 3.1837e-04 - val_loss: 1.5437e-04
# Epoch 16/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.9357e-04 - val_loss: 1.2531e-04
# Epoch 17/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.7033e-04 - val_loss: 1.1740e-04
# Epoch 18/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.4577e-04 - val_loss: 1.2743e-04
# Epoch 19/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.3922e-04 - val_loss: 1.1007e-04
# Epoch 20/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.3044e-04 - val_loss: 1.2841e-04
# Epoch 21/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.1650e-04 - val_loss: 1.0702e-04
# Epoch 22/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.2698e-04 - val_loss: 1.4403e-04
# Epoch 23/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0264e-04 - val_loss: 1.0833e-04
# Epoch 24/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0942e-04 - val_loss: 1.4128e-04
# Epoch 25/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9607e-04 - val_loss: 1.1771e-04
# Epoch 26/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0159e-04 - val_loss: 1.0437e-04
# Epoch 27/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9521e-04 - val_loss: 1.2456e-04
# Epoch 28/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9095e-04 - val_loss: 1.2076e-04
# Epoch 29/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8798e-04 - val_loss: 8.5021e-05
# Epoch 30/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8913e-04 - val_loss: 9.0987e-05
# Epoch 31/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8970e-04 - val_loss: 1.3223e-04
# Epoch 32/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8004e-04 - val_loss: 1.0091e-04
# Epoch 33/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8769e-04 - val_loss: 1.1762e-04
# Epoch 34/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7755e-04 - val_loss: 8.4908e-05
# Epoch 35/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8186e-04 - val_loss: 8.4495e-05
# Epoch 36/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7802e-04 - val_loss: 9.0645e-05
# Epoch 37/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7568e-04 - val_loss: 1.0147e-04
# Epoch 38/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8001e-04 - val_loss: 8.7608e-05
# Epoch 39/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7756e-04 - val_loss: 8.9559e-05
# Epoch 40/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8285e-04 - val_loss: 1.1230e-04
# Epoch 41/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6951e-04 - val_loss: 1.1108e-04
# Epoch 42/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7790e-04 - val_loss: 9.8049e-05
# Epoch 43/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8247e-04 - val_loss: 1.3724e-04
# Epoch 44/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7060e-04 - val_loss: 1.0145e-04
# Epoch 45/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7534e-04 - val_loss: 1.0483e-04
# Epoch 46/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7382e-04 - val_loss: 1.0762e-04
# Epoch 47/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7194e-04 - val_loss: 9.2286e-05
# Epoch 48/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7363e-04 - val_loss: 1.4771e-04
# Epoch 49/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7420e-04 - val_loss: 1.3623e-04
# Epoch 50/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6614e-04 - val_loss: 1.0080e-04
# Epoch 51/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6857e-04 - val_loss: 1.2051e-04
# Epoch 52/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7392e-04 - val_loss: 1.3936e-04
# Epoch 53/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6996e-04 - val_loss: 1.1372e-04
# Epoch 54/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6880e-04 - val_loss: 1.2637e-04
# Epoch 55/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6691e-04 - val_loss: 9.8722e-05
# Epoch 56/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6613e-04 - val_loss: 1.0297e-04
# Epoch 57/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6984e-04 - val_loss: 1.0140e-04
# Epoch 58/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6598e-04 - val_loss: 9.4100e-05
# Epoch 59/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7157e-04 - val_loss: 1.6754e-04
# Epoch 60/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7725e-04 - val_loss: 1.1983e-04
# Epoch 61/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7709e-04 - val_loss: 1.3615e-04
# Epoch 62/200
# 501/501 [==============================] - 1s 2ms/step - loss: 2.1042e-04 - val_loss: 1.1028e-04
# Epoch 63/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8443e-04 - val_loss: 8.8820e-05
# Epoch 64/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7235e-04 - val_loss: 9.9299e-05
# Epoch 65/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9066e-04 - val_loss: 1.2693e-04
# Epoch 66/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7393e-04 - val_loss: 8.4973e-05
# Epoch 67/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6745e-04 - val_loss: 1.0582e-04
# Epoch 68/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8648e-04 - val_loss: 1.3879e-04
# Epoch 69/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8344e-04 - val_loss: 1.1976e-04
# Epoch 70/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7769e-04 - val_loss: 1.0025e-04
# Epoch 71/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7392e-04 - val_loss: 9.4808e-05
# Epoch 72/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7641e-04 - val_loss: 1.0570e-04
# Epoch 73/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8691e-04 - val_loss: 1.8837e-04
# Epoch 74/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8165e-04 - val_loss: 1.0341e-04
# Epoch 75/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6318e-04 - val_loss: 8.3604e-05
# Epoch 76/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7274e-04 - val_loss: 9.5638e-05
# Epoch 77/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7356e-04 - val_loss: 9.1760e-05
# Epoch 78/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7224e-04 - val_loss: 1.1294e-04
# Epoch 79/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7377e-04 - val_loss: 9.1370e-05
# Epoch 80/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6964e-04 - val_loss: 8.7923e-05
# Epoch 81/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7259e-04 - val_loss: 1.0269e-04
# Epoch 82/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7570e-04 - val_loss: 8.9486e-05
# Epoch 83/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6988e-04 - val_loss: 8.8839e-05
# Epoch 84/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7279e-04 - val_loss: 8.6409e-05
# Epoch 85/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6763e-04 - val_loss: 9.3681e-05
# Epoch 86/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6474e-04 - val_loss: 8.7019e-05
# Epoch 87/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6913e-04 - val_loss: 9.1170e-05
# Epoch 88/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7186e-04 - val_loss: 9.1523e-05
# Epoch 89/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6845e-04 - val_loss: 9.1702e-05
# Epoch 90/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6932e-04 - val_loss: 8.7698e-05
# Epoch 91/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6978e-04 - val_loss: 1.0051e-04
# Epoch 92/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6978e-04 - val_loss: 8.6059e-05
# Epoch 93/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6301e-04 - val_loss: 8.1090e-05
# Epoch 94/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6802e-04 - val_loss: 8.4998e-05
# Epoch 95/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5998e-04 - val_loss: 8.4810e-05
# Epoch 96/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6829e-04 - val_loss: 9.6875e-05
# Epoch 97/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7273e-04 - val_loss: 9.4762e-05
# Epoch 98/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6329e-04 - val_loss: 8.7294e-05
# Epoch 99/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6558e-04 - val_loss: 9.5127e-05
# Epoch 100/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6649e-04 - val_loss: 8.2138e-05
# Epoch 101/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6096e-04 - val_loss: 9.7810e-05
# Epoch 102/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7025e-04 - val_loss: 9.5972e-05
# Epoch 103/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6383e-04 - val_loss: 9.1757e-05
# Epoch 104/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7210e-04 - val_loss: 8.2571e-05
# Epoch 105/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6475e-04 - val_loss: 8.1708e-05
# Epoch 106/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6416e-04 - val_loss: 7.7409e-05
# Epoch 107/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6130e-04 - val_loss: 8.1599e-05
# Epoch 108/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6151e-04 - val_loss: 8.2706e-05
# Epoch 109/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6545e-04 - val_loss: 8.3826e-05
# Epoch 110/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6387e-04 - val_loss: 9.0245e-05
# Epoch 111/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6977e-04 - val_loss: 8.3777e-05
# Epoch 112/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6660e-04 - val_loss: 7.2842e-05
# Epoch 113/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6292e-04 - val_loss: 9.2264e-05
# Epoch 114/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6376e-04 - val_loss: 7.3054e-05
# Epoch 115/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5757e-04 - val_loss: 8.8220e-05
# Epoch 116/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6284e-04 - val_loss: 7.6255e-05
# Epoch 117/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5464e-04 - val_loss: 8.5549e-05
# Epoch 118/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6210e-04 - val_loss: 9.1124e-05
# Epoch 119/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5991e-04 - val_loss: 8.1469e-05
# Epoch 120/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6980e-04 - val_loss: 7.7374e-05
# Epoch 121/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5871e-04 - val_loss: 7.7398e-05
# Epoch 122/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6184e-04 - val_loss: 8.8584e-05
# Epoch 123/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6007e-04 - val_loss: 8.1970e-05
# Epoch 124/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5866e-04 - val_loss: 8.2196e-05
# Epoch 125/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5724e-04 - val_loss: 8.0578e-05
# Epoch 126/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6136e-04 - val_loss: 8.0975e-05
# Epoch 127/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6240e-04 - val_loss: 8.0046e-05
# Epoch 128/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5674e-04 - val_loss: 8.4651e-05
# Epoch 129/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6098e-04 - val_loss: 8.1092e-05
# Epoch 130/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5928e-04 - val_loss: 7.7149e-05
# Epoch 131/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6123e-04 - val_loss: 8.0834e-05
# Epoch 132/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6014e-04 - val_loss: 7.3647e-05
# Epoch 133/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5466e-04 - val_loss: 7.8980e-05
# Epoch 134/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6205e-04 - val_loss: 9.0111e-05
# Epoch 135/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6147e-04 - val_loss: 7.7572e-05
# Epoch 136/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5421e-04 - val_loss: 7.9192e-05
# Epoch 137/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5304e-04 - val_loss: 8.3705e-05
# Epoch 138/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5995e-04 - val_loss: 8.1587e-05
# Epoch 139/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6030e-04 - val_loss: 8.1160e-05
# Epoch 140/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5878e-04 - val_loss: 7.8272e-05
# Epoch 141/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6234e-04 - val_loss: 7.6260e-05
# Epoch 142/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5767e-04 - val_loss: 7.8102e-05
# Epoch 143/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5827e-04 - val_loss: 6.8846e-05
# Epoch 144/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5343e-04 - val_loss: 7.4359e-05
# Epoch 145/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5111e-04 - val_loss: 7.8809e-05
# Epoch 146/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5780e-04 - val_loss: 7.9223e-05
# Epoch 147/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5573e-04 - val_loss: 8.2043e-05
# Epoch 148/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5723e-04 - val_loss: 9.1005e-05
# Epoch 149/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6114e-04 - val_loss: 7.9656e-05
# Epoch 150/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5943e-04 - val_loss: 8.0901e-05
# Epoch 151/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5704e-04 - val_loss: 9.4408e-05
# Epoch 152/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5679e-04 - val_loss: 8.0863e-05
# Epoch 153/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5466e-04 - val_loss: 7.9285e-05
# Epoch 154/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5458e-04 - val_loss: 8.1394e-05
# Epoch 155/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5408e-04 - val_loss: 7.8152e-05
# Epoch 156/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6037e-04 - val_loss: 7.7000e-05
# Epoch 157/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5291e-04 - val_loss: 7.7386e-05
# Epoch 158/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5159e-04 - val_loss: 7.3979e-05
# Epoch 159/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5274e-04 - val_loss: 7.5255e-05
# Epoch 160/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5882e-04 - val_loss: 7.8510e-05
# Epoch 161/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5158e-04 - val_loss: 7.6928e-05
# Epoch 162/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5343e-04 - val_loss: 8.3365e-05
# Epoch 163/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5412e-04 - val_loss: 8.1167e-05
# Epoch 164/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5810e-04 - val_loss: 8.3570e-05
# Epoch 165/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6030e-04 - val_loss: 8.2132e-05
# Epoch 166/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5555e-04 - val_loss: 7.3695e-05
# Epoch 167/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4923e-04 - val_loss: 7.1725e-05
# Epoch 168/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5091e-04 - val_loss: 7.9692e-05
# Epoch 169/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5025e-04 - val_loss: 7.4351e-05
# Epoch 170/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5844e-04 - val_loss: 7.8896e-05
# Epoch 171/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5515e-04 - val_loss: 7.3647e-05
# Epoch 172/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5163e-04 - val_loss: 8.8309e-05
# Epoch 173/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5823e-04 - val_loss: 7.8433e-05
# Epoch 174/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5034e-04 - val_loss: 8.0046e-05
# Epoch 175/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5148e-04 - val_loss: 8.4017e-05
# Epoch 176/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5558e-04 - val_loss: 8.9942e-05
# Epoch 177/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5530e-04 - val_loss: 7.2207e-05
# Epoch 178/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4918e-04 - val_loss: 7.5033e-05
# Epoch 179/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5126e-04 - val_loss: 7.8458e-05
# Epoch 180/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5151e-04 - val_loss: 7.3075e-05
# Epoch 181/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5561e-04 - val_loss: 7.1424e-05
# Epoch 182/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5456e-04 - val_loss: 7.5122e-05
# Epoch 183/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5164e-04 - val_loss: 6.8162e-05
# Epoch 184/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4951e-04 - val_loss: 7.2223e-05
# Epoch 185/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5156e-04 - val_loss: 7.6348e-05
# Epoch 186/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5333e-04 - val_loss: 7.3433e-05
# Epoch 187/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4786e-04 - val_loss: 7.1237e-05
# Epoch 188/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4936e-04 - val_loss: 7.3109e-05
# Epoch 189/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4867e-04 - val_loss: 8.0742e-05
# Epoch 190/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5273e-04 - val_loss: 8.0340e-05
# Epoch 191/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4816e-04 - val_loss: 7.3194e-05
# Epoch 192/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5334e-04 - val_loss: 7.0084e-05
# Epoch 193/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4360e-04 - val_loss: 7.0009e-05
# Epoch 194/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5023e-04 - val_loss: 7.3480e-05
# Epoch 195/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4751e-04 - val_loss: 7.3028e-05
# Epoch 196/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5005e-04 - val_loss: 7.3034e-05
# Epoch 197/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5000e-04 - val_loss: 8.1458e-05
# Epoch 198/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5673e-04 - val_loss: 8.2542e-05
# Epoch 199/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5366e-04 - val_loss: 8.0687e-05
# Epoch 200/200
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5233e-04 - val_loss: 7.6490e-05
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               50400
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 50501 (197.27 KB)
# Trainable params: 50501 (197.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# 1095/1095 [==============================] - 1s 745us/step
# 274/274 [==============================] - 0s 767us/step
# Train Mean Absolute Error: 329.29256905978883
# Train Root Mean Squared Error: 574.5066335749399
# Test Mean Absolute Error: 340.8772263839703
# Test Root Mean Squared Error: 446.8247168093195

# %%
test_predict
# Out:
# array([[25092.873],
#        [24980.973],
#        [24565.816],
#        ...,
#        [26337.656],
#        [25893.178],
#        [24704.838]], dtype=float32)

# %%
Y_test
# Out:
# array([[25165.99904261, 25109.99931546, 24639.99991971, ...,
#         25812.00040853, 25006.99995326, 24316.99999805]])

# %%
mape_train = np.mean(np.abs((Y_train[0] - train_predict[:,0]) / Y_train[0])) * 100
mape_test = np.mean(np.abs((Y_test[0] - test_predict[:,0]) / Y_test[0])) * 100

print("Train MAPE: {}, Test MAPE: {}".format(mape_train, mape_test))
# Out:
# Train MAPE: 6.708990578052999, Test MAPE: 1.359931111005935

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
idx = 500
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[0][:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
# Get forecast of 10 years or 120 months steps ahead in future
# forecast = model.get_forecast(steps= 120)

# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import LSTM, Dense,Dropout

# %%
df_demand.isnull().sum()
# Out:
# Local time    0
# DF            0
# Adjusted D    0
# dtype: int64

# %%
# close_data = df['Adjusted D'].values
# close_data = close_data.reshape((-1,1))

# split_percent = 0.80
# split = int(split_percent*len(close_data))

# close_train = close_data[:split]
# close_test = close_data[split:]

# date_train = df['Local time'][:split]
# date_test = df['Local time'][split:]

# print(len(close_train))
# print(len(close_test))
scaler = MinMaxScaler(feature_range=(0, 1))
# dataset = np.reshape(dataset, (-1, 1)) # reshape to one feature; required for the models
# scaler = MinMaxScaler(feature_range=(0, 1))
# dataset = scaler.fit_transform(dataset)

close_data = df_demand['Adjusted D'].values
close_data = close_data.reshape((-1,1))
close_data = scaler.fit_transform(close_data)

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df_demand['Local time'][:split]
date_test = df_demand['Local time'][split:]

print(len(close_train))
print(len(close_test))
# Out:
# 35059
# 8765

# %%
close_data
# Out:
# array([[0.44605598],
#        [0.42965355],
#        [0.41499315],
#        ...,
#        [0.48919554],
#        [0.47568996],
#        [0.46788021]])

# %%
look_back = 25

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=70)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=70)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
# model = Sequential()
# model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test),verbose=1, shuffle=False)
model = Sequential()
model.add(LSTM(100,input_shape=(look_back,1)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

num_epochs = 20
history= model.fit(train_generator, epochs=num_epochs,validation_data=test_generator,verbose=1, shuffle=False)
# Out:
# Epoch 1/20
# 501/501 [==============================] - 12s 20ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 2/20
# 501/501 [==============================] - 9s 18ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 3/20
# 501/501 [==============================] - 9s 18ms/step - loss: 0.0013 - val_loss: 8.8400e-04
# Epoch 4/20
# 501/501 [==============================] - 9s 18ms/step - loss: 0.0010 - val_loss: 7.4486e-04
# Epoch 5/20
# 501/501 [==============================] - 9s 18ms/step - loss: 8.6549e-04 - val_loss: 5.2345e-04
# Epoch 6/20
# 501/501 [==============================] - 9s 18ms/step - loss: 7.6054e-04 - val_loss: 5.1735e-04
# Epoch 7/20
# 501/501 [==============================] - 9s 18ms/step - loss: 6.7370e-04 - val_loss: 4.2135e-04
# Epoch 8/20
# 501/501 [==============================] - 9s 18ms/step - loss: 5.9468e-04 - val_loss: 3.4721e-04
# Epoch 9/20
# 501/501 [==============================] - 9s 18ms/step - loss: 5.2381e-04 - val_loss: 2.8280e-04
# Epoch 10/20
# 501/501 [==============================] - 9s 18ms/step - loss: 4.7227e-04 - val_loss: 3.0896e-04
# Epoch 11/20
# 501/501 [==============================] - 9s 18ms/step - loss: 4.0741e-04 - val_loss: 2.8022e-04
# Epoch 12/20
# 501/501 [==============================] - 9s 18ms/step - loss: 3.7784e-04 - val_loss: 2.3363e-04
# Epoch 13/20
# 501/501 [==============================] - 9s 18ms/step - loss: 3.3307e-04 - val_loss: 1.7068e-04
# Epoch 14/20
# 501/501 [==============================] - 9s 18ms/step - loss: 3.0255e-04 - val_loss: 1.7813e-04
# Epoch 15/20
# 501/501 [==============================] - 9s 18ms/step - loss: 2.7655e-04 - val_loss: 1.4196e-04
# Epoch 16/20
# 501/501 [==============================] - 9s 18ms/step - loss: 2.4942e-04 - val_loss: 1.5911e-04
# Epoch 17/20
# 501/501 [==============================] - 9s 18ms/step - loss: 2.4027e-04 - val_loss: 1.9238e-04
# Epoch 18/20
# 501/501 [==============================] - 9s 18ms/step - loss: 2.3004e-04 - val_loss: 1.2742e-04
# Epoch 19/20
# 501/501 [==============================] - 9s 18ms/step - loss: 2.1450e-04 - val_loss: 1.3676e-04
# Epoch 20/20
# 501/501 [==============================] - 9s 18ms/step - loss: 2.1138e-04 - val_loss: 1.8876e-04

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
prediction = model.predict(test_generator)
# Out:
# 125/125 [==============================] - 1s 6ms/step

# %%
close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

# %%
def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        # train_predict = scaler.inverse_transform(train_predict)
        # out = scaler.inverse_transform(out)
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df_demand['Local time'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 48
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
(forecast)
# Out:
# array([0.46788021, 0.45090926, 0.43095359, 0.41294193, 0.3992916 ,
#        0.39188075, 0.39114898, 0.39595595, 0.40385461, 0.41187778,
#        0.41751158, 0.41938367, 0.41766208, 0.41407701, 0.41156292,
#        0.41258246, 0.41864598, 0.42978245, 0.44458854, 0.46019518,
#        0.47281244, 0.47947174, 0.47928956, 0.47223321, 0.45951512,
#        0.44370976, 0.42818996, 0.41582969, 0.40843239, 0.40650123,
#        0.40917364, 0.41443419, 0.41966054, 0.42244217, 0.42141455,
#        0.41674376, 0.41003409, 0.40373749, 0.40036622, 0.40179303,
#        0.40877086, 0.42067224, 0.43549719, 0.45023918, 0.46164715,
#        0.46720403, 0.4659265 , 0.45862415, 0.44754326])

# %%
forecastout = forecast.reshape((-1, 1))

# %%
forecastout = scaler.inverse_transform(forecastout)

# %%
forecastout
# Out:
# array([[23918.        ],
#        [23050.95393682],
#        [22031.41901845],
#        [21111.20334053],
#        [20413.80808705],
#        [20035.18755102],
#        [19997.80161464],
#        [20243.38948661],
#        [20646.93195009],
#        [21056.83583909],
#        [21344.66674352],
#        [21440.3119486 ],
#        [21352.3558768 ],
#        [21169.19463152],
#        [21040.74956322],
#        [21092.83773148],
#        [21402.62301469],
#        [21971.58538067],
#        [22728.02860999],
#        [23525.37193799],
#        [24169.98776251],
#        [24510.21135533],
#        [24500.90369755],
#        [24140.39449626],
#        [23490.62771374],
#        [22683.1316846 ],
#        [21890.2252149 ],
#        [21258.73877579],
#        [20880.81102306],
#        [20782.14802349],
#        [20918.68114644],
#        [21187.44300032],
#        [21454.45690864],
#        [21596.57036299],
#        [21544.06956995],
#        [21305.43846035],
#        [20962.64167243],
#        [20640.94812953],
#        [20468.71002132],
#        [20541.60605007],
#        [20898.10319865],
#        [21506.14463294],
#        [22263.55166847],
#        [23016.71978378],
#        [23599.5530417 ],
#        [23883.45411384],
#        [23818.18479174],
#        [23445.10804468],
#        [22878.98532891]])

# %%
# Define the start and end dates for the range
start_date = '2024-01-01'
end_date = '2024-01-31'

#filter the DataFrame
df_Jan24 = df[(df['Local time'] >= start_date) & (df['Local time'] <= end_date)]
column_demand =['Local time','DF','Adjusted D']
df_Jan24 = df_Jan24[column_demand]

# %%
df_Jan24=df_Jan24.head(49)

# %%
df_Jan24['Model_forecast']=forecastout
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_560\2544081355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Jan24['Model_forecast']=forecastout

# %%
df_Jan24
# Out:
#                Local time       DF  Adjusted D  Model_forecast
# 74544 2024-01-01 00:00:00  22052.0     23066.0    23918.000000
# 74545 2024-01-01 01:00:00  21350.0     22365.0    23050.953937
# 74546 2024-01-01 02:00:00  20538.0     21604.0    22031.419018
# 74547 2024-01-01 03:00:00  20008.0     21007.0    21111.203341
# 74548 2024-01-01 04:00:00  19605.0     20402.0    20413.808087
# 74549 2024-01-01 05:00:00  19635.0     20119.0    20035.187551
# 74550 2024-01-01 06:00:00  20003.0     19740.0    19997.801615
# 74551 2024-01-01 07:00:00  20690.0     20059.0    20243.389487
# 74552 2024-01-01 08:00:00  21006.0     20697.0    20646.931950
# 74553 2024-01-01 09:00:00  20285.0     21060.0    21056.835839
# 74554 2024-01-01 10:00:00  19084.0     20827.0    21344.666744
# 74555 2024-01-01 11:00:00  17958.0     20608.0    21440.311949
# 74556 2024-01-01 12:00:00  17158.0     20707.0    21352.355877
# 74557 2024-01-01 13:00:00  16974.0     20191.0    21169.194632
# 74558 2024-01-01 14:00:00  17339.0     19778.0    21040.749563
# 74559 2024-01-01 15:00:00  18339.0     19756.0    21092.837731
# 74560 2024-01-01 16:00:00  20092.0     19820.0    21402.623015
# 74561 2024-01-01 17:00:00  22763.0     20302.0    21971.585381
# 74562 2024-01-01 18:00:00  25490.0     22243.0    22728.028610
# 74563 2024-01-01 19:00:00  25744.0     24523.0    23525.371938
# 74564 2024-01-01 20:00:00  25499.0     24851.0    24169.987763
# 74565 2024-01-01 21:00:00  25159.0     24529.0    24510.211355
# 74566 2024-01-01 22:00:00  24733.0     24327.0    24500.903698
# 74567 2024-01-01 23:00:00  23467.0     24078.0    24140.394496
# 74568 2024-01-02 00:00:00  22266.0     22808.0    23490.627714
# 74569 2024-01-02 01:00:00  21272.0     21576.0    22683.131685
# 74570 2024-01-02 02:00:00  20528.0     20779.0    21890.225215
# 74571 2024-01-02 03:00:00  20061.0     20227.0    21258.738776
# 74572 2024-01-02 04:00:00  19952.0     19834.0    20880.811023
# 74573 2024-01-02 05:00:00  20317.0     19611.0    20782.148023
# 74574 2024-01-02 06:00:00  21510.0     20025.0    20918.681146
# 74575 2024-01-02 07:00:00  23401.0     21422.0    21187.443000
# 74576 2024-01-02 08:00:00  24757.0     23274.0    21454.456909
# 74577 2024-01-02 09:00:00  24543.0     24578.0    21596.570363
# 74578 2024-01-02 10:00:00  23667.0     25319.0    21544.069570
# 74579 2024-01-02 11:00:00  22874.0     25332.0    21305.438460
# 74580 2024-01-02 12:00:00  22040.0     24774.0    20962.641672
# 74581 2024-01-02 13:00:00  21609.0     24306.0    20640.948130
# 74582 2024-01-02 14:00:00  21546.0     23267.0    20468.710021
# 74583 2024-01-02 15:00:00  22057.0     23088.0    20541.606050
# 74584 2024-01-02 16:00:00  23164.0     23720.0    20898.103199
# 74585 2024-01-02 17:00:00  24841.0     24304.0    21506.144633
# 74586 2024-01-02 18:00:00  26930.0     25631.0    22263.551668
# 74587 2024-01-02 19:00:00  27149.0     27425.0    23016.719784
# 74588 2024-01-02 20:00:00  26797.0     27329.0    23599.553042
# 74589 2024-01-02 21:00:00  26175.0     26871.0    23883.454114
# 74590 2024-01-02 22:00:00  25384.0     26561.0    23818.184792
# 74591 2024-01-02 23:00:00  23935.0     25692.0    23445.108045
# 74592 2024-01-03 00:00:00  22544.0     24252.0    22878.985329

# %%
# Plotting Adjusted D with blue color
plt.plot(df_Jan24['Adjusted D'], color='blue', label='Adjusted D')

# Plotting Model_forecast with red color
plt.plot(df_Jan24['Model_forecast'], color='red', label='Model_forecast')

# Plotting DF with green color
plt.plot(df_Jan24['DF'], color='green', label='DF')

plt.xlabel('Index')  # Assuming the x-axis represents the index of the DataFrame
plt.ylabel('Values')
plt.title('Visualization of Adjusted D, Model_forecast, and DF')
plt.legend()  # Adding legend to differentiate the lines
plt.show()

# %%
# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(df_Jan24['Adjusted D'] - df_Jan24['DF']))

# Calculate Mean Squared Error (MSE)
mse = np.mean((df_Jan24['Adjusted D'] - df_Jan24['DF'])**2)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 1219.6734693877552
# Mean Squared Error (MSE): 2328169.7959183673
# Root Mean Squared Error (RMSE): 1525.834131194596

# %%
# Calculate Mean Absolute Error (MAE)
mae = np.mean(np.abs(df_Jan24['Adjusted D'] - df_Jan24['Model_forecast']))

# Calculate Mean Squared Error (MSE)
mse = np.mean((df_Jan24['Adjusted D'] - df_Jan24['Model_forecast'])**2)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 1491.477052736039
# Mean Squared Error (MSE): 3884493.9933017995
# Root Mean Squared Error (RMSE): 1970.9119699524379

# %%
import pandas as pd

# Define the start and end dates
start_date = '2024-01-01 00:00:00'
end_date = '2024-12-31 23:00:00'

# Generate hourly time values for the year 2024
hourly_time_values = pd.date_range(start=start_date, end=end_date, freq='H')

# Create a DataFrame to store the hourly time values
df_2024 = pd.DataFrame({'Hourly_Time': hourly_time_values})

# Display the DataFrame
(df_2024)
# Out:
#              Hourly_Time
# 0    2024-01-01 00:00:00
# 1    2024-01-01 01:00:00
# 2    2024-01-01 02:00:00
# 3    2024-01-01 03:00:00
# 4    2024-01-01 04:00:00
# ...                  ...
# 8779 2024-12-31 19:00:00
# 8780 2024-12-31 20:00:00
# 8781 2024-12-31 21:00:00
# 8782 2024-12-31 22:00:00
# 8783 2024-12-31 23:00:00
#
# [8784 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
df = df_demand[['Local time','Adjusted D']]

# %%
df['Local time'] = pd.to_datetime(df['Local time'])
df.set_axis(df['Local time'], inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15428\3272249344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Local time'] = pd.to_datetime(df['Local time'])
# C:\Users\USER\AppData\Local\Temp\ipykernel_15428\3272249344.py:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis(df['Local time'], inplace=True)

# %%
df
# Out:
#                              Local time  Adjusted D
# Local time
# 2019-01-01 00:00:00 2019-01-01 00:00:00     22803.0
# 2019-01-01 01:00:00 2019-01-01 01:00:00     21965.0
# 2019-01-01 02:00:00 2019-01-01 02:00:00     21216.0
# 2019-01-01 03:00:00 2019-01-01 03:00:00     20631.0
# 2019-01-01 04:00:00 2019-01-01 04:00:00     20299.0
# ...                                 ...         ...
# 2023-12-31 19:00:00 2023-12-31 19:00:00     25999.0
# 2023-12-31 20:00:00 2023-12-31 20:00:00     25812.0
# 2023-12-31 21:00:00 2023-12-31 21:00:00     25007.0
# 2023-12-31 22:00:00 2023-12-31 22:00:00     24317.0
# 2023-12-31 23:00:00 2023-12-31 23:00:00     23918.0
#
# [43824 rows x 2 columns]

# %%
# close_data = df['Adjusted D'].values
# close_data = close_data.reshape((-1,1))

# split_percent = 0.80
# split = int(split_percent*len(close_data))

# close_train = close_data[:split]
# close_test = close_data[split:]

# date_train = df['Local time'][:split]
# date_test = df['Local time'][split:]

# print(len(close_train))
# print(len(close_test))
scaler = MinMaxScaler(feature_range=(0, 1))
# dataset = np.reshape(dataset, (-1, 1)) # reshape to one feature; required for the models
# scaler = MinMaxScaler(feature_range=(0, 1))
# dataset = scaler.fit_transform(dataset)

close_data = df['Adjusted D'].values
close_data = close_data.reshape((-1,1))
close_data = scaler.fit_transform(close_data)

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df['Local time'][:split]
date_test = df['Local time'][split:]

print(len(close_train))
print(len(close_test))
# Out:
# 35059
# 8765

# %%
look_back = 24

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
# model = Sequential()
# model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test),verbose=1, shuffle=False)
model = Sequential()
model.add(
    LSTM(100,
        activation='relu',
        input_shape=(look_back,1))
)
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

num_epochs = 100
model.fit(train_generator, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/100
# 1752/1752 [==============================] - 13s 7ms/step - loss: 55074960.0000
# Epoch 2/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 25187098.0000
# Epoch 3/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 99748216.0000
# Epoch 4/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 23903830.0000
# Epoch 5/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 20428694.0000
# Epoch 6/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 18560230.0000
# Epoch 7/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 17538798.0000
# Epoch 8/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13772459.0000
# Epoch 9/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13191144.0000
# Epoch 10/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12675868.0000
# Epoch 11/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11905200.0000
# Epoch 12/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 17790958.0000
# Epoch 13/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 20669290.0000
# Epoch 14/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 19121612.0000
# Epoch 15/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 16669457.0000
# Epoch 16/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 16850970.0000
# Epoch 17/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14649128.0000
# Epoch 18/100
# 1752/1752 [==============================] - 11s 7ms/step - loss: 14209857.0000
# Epoch 19/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14049238.0000
# Epoch 20/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 17324880.0000
# Epoch 21/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14267523.0000
# Epoch 22/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13628605.0000
# Epoch 23/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13189230.0000
# Epoch 24/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12546885.0000
# Epoch 25/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12515325.0000
# Epoch 26/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12101613.0000
# Epoch 27/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13773468.0000
# Epoch 28/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14305788.0000
# Epoch 29/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14116571.0000
# Epoch 30/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13394575.0000
# Epoch 31/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13050011.0000
# Epoch 32/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13343145.0000
# Epoch 33/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 13133331.0000
# Epoch 34/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12970763.0000
# Epoch 35/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11282984.0000
# Epoch 36/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10107233.0000
# Epoch 37/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10151431.0000
# Epoch 38/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9566361.0000
# Epoch 39/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9503074.0000
# Epoch 40/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9521080.0000
# Epoch 41/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12796200.0000
# Epoch 42/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11675981.0000
# Epoch 43/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11368624.0000
# Epoch 44/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9872291.0000
# Epoch 45/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10093514.0000
# Epoch 46/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9624954.0000
# Epoch 47/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9656908.0000
# Epoch 48/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10847807.0000
# Epoch 49/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11556739.0000
# Epoch 50/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10769200.0000
# Epoch 51/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11115915.0000
# Epoch 52/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10955193.0000
# Epoch 53/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10825067.0000
# Epoch 54/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10311230.0000
# Epoch 55/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11234943.0000
# Epoch 56/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11274094.0000
# Epoch 57/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11218805.0000
# Epoch 58/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 1573470994432.0000
# Epoch 59/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 73075952.0000
# Epoch 60/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 36442332.0000
# Epoch 61/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 22814932.0000
# Epoch 62/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 18576612.0000
# Epoch 63/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 18022494.0000
# Epoch 64/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 21249522.0000
# Epoch 65/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 16784306.0000
# Epoch 66/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14801465.0000
# Epoch 67/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 15603310.0000
# Epoch 68/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14103846.0000
# Epoch 69/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 35455116.0000
# Epoch 70/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 16781852.0000
# Epoch 71/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 14268662.0000
# Epoch 72/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12431646.0000
# Epoch 73/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11446640.0000
# Epoch 74/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10723680.0000
# Epoch 75/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10930459.0000
# Epoch 76/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11336053.0000
# Epoch 77/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10645384.0000
# Epoch 78/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11051657.0000
# Epoch 79/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10688394.0000
# Epoch 80/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10526036.0000
# Epoch 81/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12137832.0000
# Epoch 82/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12125655.0000
# Epoch 83/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12231986.0000
# Epoch 84/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12235170.0000
# Epoch 85/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12344592.0000
# Epoch 86/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 12645961.0000
# Epoch 87/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10374704.0000
# Epoch 88/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10457702.0000
# Epoch 89/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10971407.0000
# Epoch 90/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9998905.0000
# Epoch 91/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10119594.0000
# Epoch 92/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10196894.0000
# Epoch 93/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10926878.0000
# Epoch 94/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 9992881.0000
# Epoch 95/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11151344.0000
# Epoch 96/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 11415170.0000
# Epoch 97/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10848338.0000
# Epoch 98/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10631274.0000
# Epoch 99/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10537491.0000
# Epoch 100/100
# 1752/1752 [==============================] - 12s 7ms/step - loss: 10566400.0000

# %%
prediction = model.predict(test_generator)
# Out:
# 8741/8741 [==============================] - 11s 1ms/step

# %%
import plotly.graph_objs as go

# %%
close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

# trace1 = go.Scatter(
#     x = date_train,
#     y = close_train,
#     mode = 'lines',
#     name = 'Data'
# )
# trace2 = go.Scatter(
#     x = date_test,
#     y = prediction,
#     mode = 'lines',
#     name = 'Prediction'
# )
# trace3 = go.Scatter(
#     x = date_test,
#     y = close_test,
#     mode='lines',
#     name = 'Ground Truth'
# )
# layout = go.Layout(
#     title = "Google Stock",
#     xaxis = {'title' : "Date"},
#     yaxis = {'title' : "Close"}
# )
# fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
# fig.show()

# %%
close_data = close_data.reshape((-1))

def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Local time'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 100
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
(forecast)
# Out:
# array([23918.        , 23180.59179688, 22087.421875  , 20929.85546875,
#        19941.52148438, 19228.80664062, 18806.23046875, 18638.19140625,
#        18691.20703125, 18941.85351562, 19283.1015625 , 19666.85351562,
#        20014.48828125, 20295.59179688, 20498.67773438, 20644.8046875 ,
#        20831.359375  , 21162.78320312, 21548.54296875, 21948.50390625,
#        22246.90820312, 22356.2109375 , 22239.84960938, 21909.70703125,
#        21402.91796875, 20757.76171875, 20025.33984375, 19275.58398438,
#        18583.234375  , 18012.49804688, 17606.7734375 , 17381.04101562,
#        17323.59375   , 17401.65429688, 17573.84765625, 17797.39257812,
#        18035.4296875 , 18266.78320312, 18490.00976562, 18714.16015625,
#        18953.5       , 19210.74414062, 19470.75195312, 19702.00390625,
#        19860.54492188, 19905.8671875 , 19812.5703125 , 19577.27929688,
#        19213.65820312, 18749.23046875, 18222.32617188, 17678.03515625,
#        17162.5859375 , 16716.71484375, 16370.32617188, 16140.91699219,
#        16029.23535156, 16021.2265625 , 16093.80859375, 16222.75878906,
#        16387.36132812, 16573.08398438, 16771.55664062, 16978.4375    ,
#        17189.8359375 , 17398.26757812, 17590.37109375, 17745.734375  ,
#        17840.46679688, 17853.33789062, 17770.60742188, 17590.31640625,
#        17321.2578125 , 16981.00976562, 16594.1640625 , 16189.74023438,
#        15798.03515625, 15446.8125    , 15157.8984375 , 14946.56542969,
#        14817.93554688, 14767.8671875 , 14785.72753906, 14857.44433594,
#        14969.22851562, 15109.40722656, 15268.54101562, 15438.53613281,
#        15611.10449219, 15776.44628906, 15921.94726562, 16032.59179688,
#        16093.53515625, 16092.54980469, 16022.24316406, 15881.81835938,
#        15677.92285156, 15422.58203125, 15132.12304688, 14825.73242188,
#        14523.73535156])

# %%
# Read the Excel file into a pandas DataFrame
df_read = pd.read_excel(file_path)

# %%
df_read['Local time'] = pd.to_datetime(df_read['Local time'])

# Define the start and end dates for the range
start_date = '2024-01-01'
end_date = '2024-01-31'

#filter the DataFrame
df_Jan24 = df_read[(df_read['Local time'] >= start_date) & (df_read['Local time'] <= end_date)]
column_demand =['Local time','DF','Adjusted D']
df_Jan24 = df_Jan24[column_demand]

# %%
df_Jan24=df_Jan24.head(101)

# %%
df_Jan24
# Out:
#                Local time       DF  Adjusted D
# 74544 2024-01-01 00:00:00  22052.0     23066.0
# 74545 2024-01-01 01:00:00  21350.0     22365.0
# 74546 2024-01-01 02:00:00  20538.0     21604.0
# 74547 2024-01-01 03:00:00  20008.0     21007.0
# 74548 2024-01-01 04:00:00  19605.0     20402.0
# ...                   ...      ...         ...
# 74640 2024-01-05 00:00:00  23669.0     24875.0
# 74641 2024-01-05 01:00:00  21695.0     23809.0
# 74642 2024-01-05 02:00:00  21027.0     22782.0
# 74643 2024-01-05 03:00:00  20486.0     21926.0
# 74644 2024-01-05 04:00:00  20335.0     21340.0
#
# [101 rows x 3 columns]

# %%
df_Jan24['Model_forecast']=list(forecast)

# %%
df_Jan24.head(48)
# Out:
#                Local time       DF  Adjusted D  Model_forecast
# 74544 2024-01-01 00:00:00  22052.0     23066.0    23918.000000
# 74545 2024-01-01 01:00:00  21350.0     22365.0    23180.591797
# 74546 2024-01-01 02:00:00  20538.0     21604.0    22087.421875
# 74547 2024-01-01 03:00:00  20008.0     21007.0    20929.855469
# 74548 2024-01-01 04:00:00  19605.0     20402.0    19941.521484
# 74549 2024-01-01 05:00:00  19635.0     20119.0    19228.806641
# 74550 2024-01-01 06:00:00  20003.0     19740.0    18806.230469
# 74551 2024-01-01 07:00:00  20690.0     20059.0    18638.191406
# 74552 2024-01-01 08:00:00  21006.0     20697.0    18691.207031
# 74553 2024-01-01 09:00:00  20285.0     21060.0    18941.853516
# 74554 2024-01-01 10:00:00  19084.0     20827.0    19283.101562
# 74555 2024-01-01 11:00:00  17958.0     20608.0    19666.853516
# 74556 2024-01-01 12:00:00  17158.0     20707.0    20014.488281
# 74557 2024-01-01 13:00:00  16974.0     20191.0    20295.591797
# 74558 2024-01-01 14:00:00  17339.0     19778.0    20498.677734
# 74559 2024-01-01 15:00:00  18339.0     19756.0    20644.804688
# 74560 2024-01-01 16:00:00  20092.0     19820.0    20831.359375
# 74561 2024-01-01 17:00:00  22763.0     20302.0    21162.783203
# 74562 2024-01-01 18:00:00  25490.0     22243.0    21548.542969
# 74563 2024-01-01 19:00:00  25744.0     24523.0    21948.503906
# 74564 2024-01-01 20:00:00  25499.0     24851.0    22246.908203
# 74565 2024-01-01 21:00:00  25159.0     24529.0    22356.210938
# 74566 2024-01-01 22:00:00  24733.0     24327.0    22239.849609
# 74567 2024-01-01 23:00:00  23467.0     24078.0    21909.707031
# 74568 2024-01-02 00:00:00  22266.0     22808.0    21402.917969
# 74569 2024-01-02 01:00:00  21272.0     21576.0    20757.761719
# 74570 2024-01-02 02:00:00  20528.0     20779.0    20025.339844
# 74571 2024-01-02 03:00:00  20061.0     20227.0    19275.583984
# 74572 2024-01-02 04:00:00  19952.0     19834.0    18583.234375
# 74573 2024-01-02 05:00:00  20317.0     19611.0    18012.498047
# 74574 2024-01-02 06:00:00  21510.0     20025.0    17606.773438
# 74575 2024-01-02 07:00:00  23401.0     21422.0    17381.041016
# 74576 2024-01-02 08:00:00  24757.0     23274.0    17323.593750
# 74577 2024-01-02 09:00:00  24543.0     24578.0    17401.654297
# 74578 2024-01-02 10:00:00  23667.0     25319.0    17573.847656
# 74579 2024-01-02 11:00:00  22874.0     25332.0    17797.392578
# 74580 2024-01-02 12:00:00  22040.0     24774.0    18035.429688
# 74581 2024-01-02 13:00:00  21609.0     24306.0    18266.783203
# 74582 2024-01-02 14:00:00  21546.0     23267.0    18490.009766
# 74583 2024-01-02 15:00:00  22057.0     23088.0    18714.160156
# 74584 2024-01-02 16:00:00  23164.0     23720.0    18953.500000
# 74585 2024-01-02 17:00:00  24841.0     24304.0    19210.744141
# 74586 2024-01-02 18:00:00  26930.0     25631.0    19470.751953
# 74587 2024-01-02 19:00:00  27149.0     27425.0    19702.003906
# 74588 2024-01-02 20:00:00  26797.0     27329.0    19860.544922
# 74589 2024-01-02 21:00:00  26175.0     26871.0    19905.867188
# 74590 2024-01-02 22:00:00  25384.0     26561.0    19812.570312
# 74591 2024-01-02 23:00:00  23935.0     25692.0    19577.279297

# %%
mape = np.mean(np.abs((df_Jan24['Adjusted D'] - df_Jan24['Model_forecast']) / df_Jan24['Adjusted D'])) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 22.55415793408317

# %%
mape = np.mean(np.abs((df_Jan24['Adjusted D'] - df_Jan24['DF']) / df_Jan24['Adjusted D'])) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 5.47884858093444

# %%
# look_back
# batch size
# LSTM units
# num_epochs

# %%
look_back = 25

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=12)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)

# %%
# from keras.models import Sequential
# from keras.layers import LSTM, Dense
# model = Sequential()
# model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
model = Sequential()
model.add(
    LSTM(100,
        activation='relu',
        input_shape=(look_back,1))
)
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

num_epochs = 100
model.fit(train_generator, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/100
# 2920/2920 [==============================] - 18s 6ms/step - loss: 62950964.0000
# Epoch 2/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 32510218.0000
# Epoch 3/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 27737954.0000
# Epoch 4/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 22575630.0000
# Epoch 5/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 30503428.0000
# Epoch 6/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 23117754.0000
# Epoch 7/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 19281822.0000
# Epoch 8/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 17288340.0000
# Epoch 9/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15934655.0000
# Epoch 10/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15928703.0000
# Epoch 11/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13462271.0000
# Epoch 12/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13369705.0000
# Epoch 13/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12605304.0000
# Epoch 14/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11886455.0000
# Epoch 15/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11486933.0000
# Epoch 16/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10903799.0000
# Epoch 17/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10627532.0000
# Epoch 18/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10225906.0000
# Epoch 19/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11328437.0000
# Epoch 20/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11312669.0000
# Epoch 21/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10762096.0000
# Epoch 22/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12916760.0000
# Epoch 23/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11397538.0000
# Epoch 24/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14054645.0000
# Epoch 25/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11270448.0000
# Epoch 26/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11455005.0000
# Epoch 27/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14378608.0000
# Epoch 28/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10741856.0000
# Epoch 29/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10389922.0000
# Epoch 30/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10454556.0000
# Epoch 31/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 10984435.0000
# Epoch 32/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 68154768.0000
# Epoch 33/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 17460852.0000
# Epoch 34/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14427049.0000
# Epoch 35/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13427737.0000
# Epoch 36/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12376838.0000
# Epoch 37/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12394663.0000
# Epoch 38/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12974649.0000
# Epoch 39/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12870502.0000
# Epoch 40/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13045956.0000
# Epoch 41/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13374384.0000
# Epoch 42/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13792787.0000
# Epoch 43/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13447352.0000
# Epoch 44/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11970161.0000
# Epoch 45/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11914345.0000
# Epoch 46/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 11893177.0000
# Epoch 47/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12025214.0000
# Epoch 48/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12088724.0000
# Epoch 49/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12393225.0000
# Epoch 50/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12858516.0000
# Epoch 51/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13505553.0000
# Epoch 52/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13709598.0000
# Epoch 53/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12756579.0000
# Epoch 54/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13036520.0000
# Epoch 55/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14164718.0000
# Epoch 56/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13760139.0000
# Epoch 57/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13632251.0000
# Epoch 58/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13674931.0000
# Epoch 59/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13829293.0000
# Epoch 60/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13533271.0000
# Epoch 61/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13649292.0000
# Epoch 62/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13800830.0000
# Epoch 63/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15052931.0000
# Epoch 64/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14516188.0000
# Epoch 65/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13942274.0000
# Epoch 66/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13590984.0000
# Epoch 67/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13763481.0000
# Epoch 68/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13722852.0000
# Epoch 69/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15463592.0000
# Epoch 70/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15178214.0000
# Epoch 71/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14949572.0000
# Epoch 72/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15151286.0000
# Epoch 73/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 15231996.0000
# Epoch 74/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14999248.0000
# Epoch 75/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14981676.0000
# Epoch 76/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 14410734.0000
# Epoch 77/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13816286.0000
# Epoch 78/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13813615.0000
# Epoch 79/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13019266.0000
# Epoch 80/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13003631.0000
# Epoch 81/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12697611.0000
# Epoch 82/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13398265.0000
# Epoch 83/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12887228.0000
# Epoch 84/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12714299.0000
# Epoch 85/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12844496.0000
# Epoch 86/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12813895.0000
# Epoch 87/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12775814.0000
# Epoch 88/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12587324.0000
# Epoch 89/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 12687545.0000
# Epoch 90/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13535849.0000
# Epoch 91/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13826830.0000
# Epoch 92/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13778875.0000
# Epoch 93/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13695638.0000
# Epoch 94/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13678160.0000
# Epoch 95/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13613381.0000
# Epoch 96/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13834788.0000
# Epoch 97/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13692660.0000
# Epoch 98/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13619603.0000
# Epoch 99/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13768524.0000
# Epoch 100/100
# 2920/2920 [==============================] - 17s 6ms/step - loss: 13716157.0000

# %%
prediction = model.predict(test_generator)
# Out:
# 8740/8740 [==============================] - 11s 1ms/step

# %%
close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

# %%
close_data = close_data.reshape((-1))

def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Local time'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 100
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)
# Out:
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
df_Jan24['Model_forecast']=list(forecast)

# %%
df_Jan24
# Out:
#                Local time       DF  Adjusted D  Model_forecast
# 74544 2024-01-01 00:00:00  22052.0     23066.0    23918.000000
# 74545 2024-01-01 01:00:00  21350.0     22365.0    22749.732422
# 74546 2024-01-01 02:00:00  20538.0     21604.0    21022.292969
# 74547 2024-01-01 03:00:00  20008.0     21007.0    19492.244141
# 74548 2024-01-01 04:00:00  19605.0     20402.0    18300.011719
# ...                   ...      ...         ...             ...
# 74640 2024-01-05 00:00:00  23669.0     24875.0     8307.161133
# 74641 2024-01-05 01:00:00  21695.0     23809.0     7832.205566
# 74642 2024-01-05 02:00:00  21027.0     22782.0     7431.771973
# 74643 2024-01-05 03:00:00  20486.0     21926.0     7146.744141
# 74644 2024-01-05 04:00:00  20335.0     21340.0     6998.679199
#
# [101 rows x 4 columns]
